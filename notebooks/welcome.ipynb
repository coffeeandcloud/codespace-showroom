# %%
import pandas as pd

# %%
data = pd.read_csv("tree-inventory.csv")

# %%
data.head()
# Out:
#       ﻿Tree # Grant Number    Funder                Species       St. Address  \
# 0  2018092201     8GG17418  CAL FIRE      Platanus racemosa  3011 Rutgers Ave
# 1  2018092210     8GG17418  CAL FIRE  Lophostemon confertus     5335 Pavo St.
# 2  2018092212     8GG17418  CAL FIRE  Lophostemon confertus     5335 Pavo St.
# 3  2018092213     8GG17418  CAL FIRE  Lophostemon confertus     5335 Pavo St.
# 4  2018092217     8GG17418  CAL FIRE  Lophostemon confertus     5335 Pavo St.
#
#             Address Info        City Ownership  X Coordinate  Y Coordinate  \
# 0  SoCo -- Carver School  Long Beach    Public   -118.129321     33.811131
# 1  SoCo -- Carver School  Long Beach    Public   -118.128001     33.811555
# 2  SoCo -- Carver School  Long Beach    Public   -118.127001     33.811555
# 3  SoCo -- Carver School  Long Beach    Public   -118.127001     33.811555
# 4  SoCo -- Carver School  Long Beach    Public   -118.127001     33.811555
#
# ...
